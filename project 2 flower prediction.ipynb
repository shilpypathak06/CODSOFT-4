# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('U:\codesoft\iris_dataset.csv')

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# ...

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['target'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: target, dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df['sepal length (cm)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['sepal width (cm)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['petal length (cm)'].hist()
# Out:
# <AxesSubplot:>

# %%
df['sepal width (cm)'].hist()
# Out:
# <AxesSubplot:>

# %%
colors=['red','orange','blue']
species=['Iris-setosa ','Iris-versicolor','Iris-virginica']

# %%
for i in range (3):
    x=df[df['target']==species[i]]
    plt.scatter(x['sepal length (cm)'],x['sepal width (cm)'],c=colors[i],label=species[i])
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.legend()

# %%
for i in range (3):
    x=df[df['target']==species[i]]
    plt.scatter(x['petal length (cm)'],x['petal width (cm)'],c=colors[i],label=species[i])
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.legend()

# %%
for i in range (3):
    x=df[df['target']==species[i]]
    plt.scatter(x['sepal length (cm)'],x['petal length (cm)'],c=colors[i],label=species[i])
plt.xlabel("sepal length")
plt.ylabel("petal length")
plt.legend()

# %%
for i in range (3):
    x=df[df['target']==species[i]]
    plt.scatter(x['sepal width (cm)'],x['petal width (cm)'],c=colors[i],label=species[i])
plt.xlabel("sepal width")
plt.ylabel("petal width")
plt.legend()

# %% [markdown]
# # coorelation matrix

# %% [markdown]
# a coorelation matrix is a tabel showing correlation beteween variables .Each cell in  the tabel  shows the correlation between two variables .
# The value is in the range of -1 to 1. If two variables have high correlation,we can neglesct one variabble from those two

# %%
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.109369           0.871754
# sepal width (cm)           -0.109369          1.000000          -0.420516
# petal length (cm)           0.871754         -0.420516           1.000000
# petal width (cm)            0.817954         -0.356544           0.962757
#
#                    petal width (cm)
# sepal length (cm)          0.817954
# sepal width (cm)          -0.356544
# petal length (cm)          0.962757
# petal width (cm)           1.000000

# %%
corr=df.corr()
fig, ax=plt.subplots(figsize=(3,3))
sns.heatmap(corr,annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # label encoder

# %% [markdown]
# in machine learning we usually deal with datasets which contains multiple labels in one or more than one coloumns. these labels can be in the form of words or numbeers .label encodong refers to coverting the labels into numeric form so as to convert it into the machine -readble  form

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['species ']=le.fit_transform(df['target'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target  species
# 0  Iris-setosa         0
# 1  Iris-setosa         0
# 2  Iris-setosa         0
# 3  Iris-setosa         0
# 4  Iris-setosa         0

# %%
df.drop(["target"],axis=1,inplace=True)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0           0
# ...

# %% [markdown]
# # model trainig

# %%
from sklearn.model_selection import train_test_split
#train....
#testing..30%

# %%
X=df.drop(index=['species'])
Y=df['species']
x_train ,x_test , y_train ,y_test =train_test_split(X,Y, test_size=0.30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\3881679857.py in <module>
# ----> 1 X=df.drop(index=['species'])
#       2 Y=df['species']
#       3 x_train ,x_test , y_train ,y_test =train_test_split(X,Y, test_size=0.30)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
